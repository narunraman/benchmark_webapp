# %%
import pandas as pd

# %% [markdown]
# # DataFrame of All Tasks

# %%
df = pd.DataFrame([
    {'group_name': 'Optimization', "task_name": "Addition and Subtraction", "description": 'These are the most basic arithmetic operations and form the foundation for quantifying options in decision-making and changes in resources, costs, and benefits.', "tasks": ["Add and Subtract Integers", "Add and Subtract Decimals", "Add and Subtract Large Numbers", ], "difficulty_levels": [0, 1, 2], 'questions': ["You paid your friend's lunch bill the past two days and need to calculate how much she owes you. What is $56 + $20\nA. $76\nB. $56", 'You need to calculate the following sum. How much money do you have if you sum 40.19 and 32.53?\nA. 72.72\nB. 72.12', "You got your paycheck yesterday and spent some of it on clothes and need to calculate how much money you have left. What is $35212.23 - $9247.46?\nA. $25964.77\nB. $25124.68"]},

    {'group_name': 'Optimization', "task_name": "Multiplication and Division", "description": 'These operations are crucial for understanding the scaling of options and outcomes.', "tasks": ["Multiply and Divide Integers", "Multiply and Divide Decimals", "Multiply and Divide Large Numbers"], "difficulty_levels": [1, 2, 3], 'questions': ["You paid your friend's lunch bill the past three days and need to calculate how much she owes you. What is $40 * 3\nA. $120\nB. $102", "You got your paycheck yesterday and need to pay the government back taxes. What is $1500.87 / 10.3\nA. $145.71\nB. $123.15", 'Your friend comes up to you with the following question. What is the quotient of 812471 and 125?\nA. 6499.77\nB. 6531.23']},

    {'group_name': 'Probability', "task_name": "Compute Probabilities of Random Events", "description": 'The fundamental task of determining the likelihood of simple outcomes.', "tasks": ["Compute Probability of a Single Random Event", "Compute Probabilities of a Few Random Events", "Compute Probabilities of Many Random Events"], "difficulty_levels": [1, 2, 3], 'questions': ['What is the probability of getting a 4 when a fair six-sided dice is rolled?\nA. 1/6\nB. 1/3', "If three coins are flipped, what is the probability of getting 3 tails?\nA. 1/6\nB. 1/8", 'You draw a card from a standard deck of 52 cards. What is the probability of drawing a heart?\nA. 4/52\nB. 13/52']},

    {'group_name': 'Probability', "task_name": "Complement Rule", "description": 'Calculating the probability that an event does not occur, an essential concept in probability theory.', "tasks": ["Complement Rule with Two Outcomes", "Complement Rule with Three Outcomes"], "difficulty_levels": [1, 2], 'questions': ['You are fishing and there are two fish in the pond: carp and trout. With probability 0.85 you will catch a trout or nothing at all. How likely are you to catch a carp?.\nA. 0.78\nB. 0.15\nC. 0.69', 'You are fishing and there are two fish in the pond: carp and trout. With probability 0.85 you will catch a trout or nothing at all. How likely are you to catch a carp?.\nA. 0.78\nB. 0.15\nC. 0.69']},
    
    # {'group_name': 'Probability', "task_name": "Can Compute Joint Probabilities", "tasks": ["Can Compute Joint Probabilities", "Can Compute Joint Probabilities Harder", "Can Compute Joint Probabilities Hardest"], "difficulty_levels": [3, 4, 5], },

    # {'group_name': 'Probability', "task_name": "Can Compute Marginal Probabilities", "tasks": ["Can Compute Marginal Probabilities", "Can Compute Marginal Probabilities Harder", "Can Compute Marginal Probabilities Hardest"], "difficulty_levels": [3, 4, 5], },

    {'group_name': 'Probability', "task_name": "Bayes Rule", "description": "Bayes' Rule is essential for updating beliefs or predictions in light of new evidence. It describes the probability of an event, based on prior knowledge of conditions that might be related to the event.", "tasks": ["Can Correctly Use Bayes Rule in Multiple Choice", "Can Correctly Use Bayes Rule in Open-Ended"], "difficulty_levels": [5, 6], 'questions': ['', '']},

    {'group_name': 'Probability', "task_name": "Gambler\'s Fallacy", "description": "The incorrect belief that, if a particular event occurs more frequently than normal in the past, it is less likely to happen in the future (or vice versa), despite the fact that the probability of such an event is independent of the past. Recognizing and avoiding this fallacy prevents decision-makers from making erroneous predictions based on past events, leading to more rational and evidence-based decisions.", "tasks": ["Does Not Exhibit Gambler's Fallacy"], "difficulty_levels": [4], 'questions': ["You're at a roulette table and the ball has fallen on a black number three times in a row, do you think the ball is more likely to land on a red number for the next spin?\nA. Yes\nB. No"]},

    {'group_name': 'Optimization', "task_name": "Pick Maximum or Minimum", "description": "A simple decision rule used in many optimization scenarios, where the option with the highest/lowest value is chosen.", "tasks": ["Pick Maximum or Minimum Integers", "Pick Maximum or Minimum Decimals"], "difficulty_levels": [0, 1], 'questions': ['Which is the bigger number:\nA. 100\nB. -200', 'Would you rather receive:\nA. $211.42\nB. $921.21']},

    # {'group_name': 'Optimization', "task_name": "Unconstrained Optimization", "description": "Evaluates if a model can compute the correct answer in constrained optimization.", "tasks": ["Compute Simple Unconstrained Optimization", "Compute Difficult Unconstrained Optimization"], "difficulty_levels": [2, 3], 'questions': ['', '']},

    {'group_name': 'Optimization', "task_name": "Constrained Optimization", 'description': "Involves finding the maximum or minimum of a function subject to constraints. Many real-world decisions involve constraints (like budget, time, or resources). Understanding how to optimize within these limits is essential for effective decision-making.", "tasks": ["Compute Simple Constrained Optimization", "Compute Difficult Constrained Optimization"], "difficulty_levels": [3, 4], 'questions': ['You have 40 meters of fencing, and you want to enclose a rectangular garden in your backyard. You can use all 40 meters of the fencing. What should be the dimensions of the garden to maximize the area?\nA. \nB. ', 'You work in a small manufacturing company, and your task is to design a rectangular cardboard box with a fixed volume of 500 cubic inches. The cost of cardboard for the top and bottom of the box is $0.02 per square inch, and the cost for the sides is $0.01 per square inch. Your goal is to design the box with the least cost. What should be the dimensions of the box to minimize the cost of making it?\nA. \nB. ']},

    {'group_name': 'Logic', "task_name": "Logical Equivalence of Contrapositive", "description": "Understanding that certain statements are logically equivalent, such as a statement and its contrapositive (e.g., ``If A, then B'' is equivalent to ``if not B, then not A''). ", "tasks": ["Logical Equivalence (Contrapositive)"], "difficulty_levels": [2], 'questions': ["In a medical study, a doctor makes the following statement: 'If a patient has a high fever, then they have an infection.' Which of the following statements is logically equivalent?\nA. If a patient does not have an infection, then they do not have a high fever\nB. If a patient has a high fever, then they do not have an infection\nC. If a patient has an infection, then they definitely have a high fever."]},

    {'group_name': 'Logic', "task_name": "Categorical Syllogism", "description": "A form of deductive reasoning where a conclusion is reached based on two premises that are asserted as true. These syllogisms deal with relationships between categories. ", "tasks": ["Categorical Syllogism"], "difficulty_levels": [2], 'questions': [""]},

    {'group_name': 'Logic', "task_name": "Conditional Syllogism", "description": "These involve 'if-then' statements and are a form of reasoning where a conclusion is drawn based on a conditional premise. Conditional syllogisms are key in scenarios involving cause and effect, planning under uncertainty, and developing strategies that depend on certain conditions being met.", "tasks": ["Conditional Syllogism"], "difficulty_levels": [2], 'questions': [""]},

    {'group_name': 'Theory of Mind', "task_name": "False-Belief", "description": "Evaluates if a model can correctly distinguish between a true belief and the awareness of someone else's different, false belief.", "tasks": ["First-Order False-Belief", "Second-Order False-Belief"], "difficulty_levels": [3, 4], 'questions': ["Sarah puts her toy car in the toy box and then leaves the room. While she's gone, her dad, Roberto, moves the car from the toy box onto the toy shelf. When Sarah comes back into the room, where will she look for her toy car?\nA. Toy box\nB. Toy shelf", "Sarah puts her toy car in the toy box and then leaves the room. While she's gone, her dad, Roberto, moves the car from the toy box onto the toy shelf. When Sarah comes back into the room, where would Roberto think that Sarah would look for her toy car?\nA. Toy box\nB. Toy shelf"]},

    # {'group_name': 'Theory of Mind', "task_name": "Deceptive Appearance",  "tasks": ["Deceptive Appearance Task"], "difficulty_levels": [3], 'questions': ["You are shown a tube labeled 'Smarties' and are excited to open it, expecting to find colorful candies. When you open the tube, you discover it contains crayons instead of Smarties. What would your friend think is inside the tube if they haven't seen it?\nA. Smarties\nB. Crayons"]},

    {'group_name': 'Theory of Mind', "task_name": "Secret Information", "description": "Evaluates the ability to correctly identify information to share or keep secret.", "tasks": ["Keeping a Secret"], "difficulty_levels": [3], 'questions': ["You and your friend Sarah are going to watch a movie together. Sarah really does not like spoilers and prefers to be surprised by the plot. You have already watched the movie. When Sarah asks you about the movie, what should you do to respect her preference?\nA. Keep the twist a secret\nB. Tell her the big twist"]},

    {'group_name': 'Axioms of Utility in Deterministic Environments', "task_name": "Completeness", "description": "Every pair of alternatives is comparable. This means that for any two options, A and B, an individual can always decide if they prefer A to B, prefer B to A, or are indifferent between them.", "tasks": ["Completeness Across Two Options", "Completeness Across Three Options"], "difficulty_levels": [1, 2], 'questions': ["", ""]},

    {'group_name': 'Axioms of Utility in Deterministic Environments', "task_name": "Transitivity", "description": "If an individual prefers A to B and B to C, then they must also prefer A to C. Transitivity means that an agent's weak preferences can cycle only among choices that are indifferent.", "tasks": ["Transitivity Across Three Options", "Transitivity Across Four Options"], "difficulty_levels": [2, 3], 'questions': ["You like mojitos more than margaritas, and you like margaritas more than you like gin and tonic. Which drink would you prefer?\nA. Mojitos\nB. Gin and Tonic", 'You like Pear less than Melon, you like Jackfruit more than Melon, and you like Canistel more than Jackfruit. Which fruit you rather get?\nA. Pear\nB. Canistel']},

    {'group_name': 'Axioms of Utility in Deterministic Environments', "task_name": "Independence", "description": "Preferences between options should remain consistent regardless of the presence of other alternatives. If A is preferred to B, introducing a third option C should not change this preference.", "tasks": ["Ignores Irrelevant Alternatives"], "difficulty_levels": [4], 'questions': ["You're looking for a new coffee maker. There are two models available with varying features and costs. Which one do you pick?\nA. Brand A: price is $20, with quality rating 40 \nB. Brand B: price is $91, with quality rating 95\nYou're looking for a new coffee maker. There are three models available with varying features and costs. Which one do you pick?\nA. Brand A: price is $20, with quality rating 40\nB. Brand B: price is $91, with quality rating 95\nC. Brand C: price is $88, with quality rating 40"]},

    # {'group_name': 'Reference Independent Decision-Making', "tasks": ["Unaffected by Peer Pressure"], "difficulty_levels": [7], },

    {'group_name': 'Avoidance of Cognitive Biases in Deterministic Environments', "task_name": "Avoidance of Sunk Cost Fallacy", "description": "This occurs when individuals continue a venture or continue consuming a product because they have already invested resources (time, money, effort), even if they are not deriving joy or benefit from it. The decision is influenced by the emotional investment in the sunk costs rather than a rational assessment of future utility.", "tasks": ["Ignores Sunk Costs"], "difficulty_levels": [7], 'questions': ["Imagine that Johny is the manager of a factory projected to yield $433 million in value and $90 million has already been spent on it. Unfortunately, there was a change in the market and now the value projection of the factory falls to $51 million. Should he:\nA. Spend an additional $86 million to complete it\nB. Abandon the project."]},

    # {'group_name': 'Reference Independent Decision-Making', "tasks": ["Unaffected by Status Quo"], "difficulty_levels": [7], },

    {'group_name': 'Avoidance of Cognitive Biases in Deterministic Environments', "task_name": "Avoidance of Endowment Effect", "description": "This effect describes a situation where individuals value an object they own more than an identical object they do not own. It suggests that ownership alone increases the item's value in the owner's eyes, which is inconsistent with the objective value assumed in utility theory.", "tasks": ["Unaffected by Endowments"], "difficulty_levels": [6], 'questions': ["You are at a family event and they are raffling off sweaters and backpacks. You win a sweater in the raffle. Your sister wins a backpack and asks if you would like to trade. Do you accept the offer?\nA. Yes\nB. No\nYou are at a family event and they are raffling off sweaters and backpacks. You win a backpack in the raffle. Your sister wins a sweater and asks if you would like to trade. Do you accept the offer?\nC. Yes\nD. No"]},

    {'group_name': 'Avoidance of Cognitive Biases in Deterministic Environments', "task_name": "Consistent Discounting", "description": "This involves testing if preferences are inconsistent across different points in time. A common example is preferring immediate rewards over larger future rewards, even though waiting would lead to greater overall utility. This inconsistency often stems from an overemphasis on the present moment and underestimation of future benefits or consequences.", "tasks": ["Discounts Consistently Across a Few Time Steps"], "difficulty_levels": [5], 'questions': ['']},

    # {'group_name': 'Reference Independence', "task_name": "Recency and Primacy Bias", "description": "Evaluates the ability to correctly choose from a list at random.", "tasks": ["Can Recall a Few Objects Agnostic to Ordering", "Can Recall Many Objects Agnostic to Ordering"], "difficulty_levels": [5, 6], 'questions': ['You are shown the following list of fruits and asked to memorize it: [Strawberry, Cherry, Mango, Melon]. You are then asked to recall one element of the list. Which element do you remember?\nA. Strawberry\nB. Cherry\nC. Mango\nD. Melon', 'You are shown the following list of fruits and asked to memorize it: [Apple, Banana, Purple Mangosteen, Strawberry, Cherry, Mango, Melon]. You are then asked to recall one element of the list. Which element do you remember? Answer by saying a single word which is the element of the list you remember.\nA. Apple \nB. Banana\nC. Purple Mangosteen\nD. Strawberry\nE. Cherry\nF. Mango\nG. Melon']},

    {'group_name': 'Axioms of Utility in Stochastic Environments', "task_name": "Completeness over Lotteries", "description": "Every pair of alternatives is comparable. This means that for any two options, A and B, an individual can always decide if they prefer A to B, prefer B to A, or are indifferent between them.", "tasks": ["Completeness Across Two Options", "Completeness Across Three Options"], "difficulty_levels": [1, 2], 'questions': ["", ""]},

    {'group_name': 'Axioms of Utility in Stochastic Environments', "task_name": "Transitivity over Lotteries", "description": "If an individual prefers A to B and B to C, then they must also prefer A to C. Transitivity means that an agent's weak preferences can cycle only among choices that are indifferent.", "tasks": ["Transitivity Across Three Options", "Transitivity Across Four Options"], "difficulty_levels": [2, 3], 'questions': [""]},

    {'group_name': 'Axioms of Utility in Stochastic Environments', "task_name": "Independence over Lotteries", "description": "Preferences between options should remain consistent regardless of the presence of other alternatives. If A is preferred to B, introducing a third option C should not change this preference.", "tasks": ["Ignores Irrelevant Alternatives"], "difficulty_levels": [4], 'questions': [""]},


    {'group_name': 'Risk Neutral Expected Utility Computations', "task_name": "Compute Expected Utility", "description": "Evaluates the ability to accurately compute expected utility: the sum of the products of each outcome's utility and its probability.", "tasks": ["Compute Expected Utility of Two Outcomes", "Compute Expected Utility of Three Outcomes", "Compute Expected Utility of Four Outcomes"], "difficulty_levels": [3, 4, 5], 'questions': ['On average, what is the sum of rolling a fair 5-sided die and a fair 86-sided die?\nA. 46.5\nB. 93.08\nC. 20.51', 'You are a city engineer considering an evacuation plan in case of a flood. Plan X has a 63% chance of evacuating 46 safely; a 24% chance of only evacuating 163 in time; and a 16% chance of failure, leading to no evacuations. What are expected number of people evacuated for Plan X?\nA. 68.1\nB. 127.39\nC. 55.34', "You are flipping a coin. If it lands heads up, you get -54.09 dollars. If the coin lands tails up, you get 83.25. How much money can you expect to receive for 4 coin flips?\nA. 233.28\nB. 317.99\nC. 155.91"]},

    {'group_name': 'Risk Neutral Expected Utility Computations', "task_name": "Maximize Expected Utility", "description": "Evaluates the ability to correctly pick the option with higher expected value.", "tasks": ["Maximize Expected Utilities of Two Outcomes", "Maximize Expected Utilities of Three Outcomes", "Maximize Expected Utilities of Four Outcomes"], "difficulty_levels": [3, 4, 5], 'questions': ['You have $100, and you can either keep it or bet it all on a coin toss with a 50% chance of winning double your bet. Which option maximizes your expected utility?\nA. Keep principal\nB. Take the bet', "You're trying to decide between two restaurants for dinner. Restaurant X always serves decent food, and you assign a utility of 7 out of 10 to it. Restaurant Y is sometimes excellent (9/10) and sometimes terrible (2/10) with equal probability. Which restaurant will you choose?\nA. Restaurant X\nB. Restaurant Y", ""]},

    # {'group_name': 'Expected Utility Theory', "task_name": "Computes Expectations with Objective Probabilities",  "tasks": ["Computes Expectations of Few Outcomes with Objective Probabilities", "Computes Expectations of Many Outcomes with Objective Probabilities", ], "difficulty_levels": [7, 8, 9], },

    # {'group_name': 'Risk Assessment', "task_name": "Risk Aversion", "description": "Evaluates the ability to correctly choose the option with the highest expected value when .", "tasks": ["Does Not Make Risk Averting Decisions"], "difficulty_levels": [6], 'questions': ['You have two job offers. Job P offers a salary of $100,000 per year with no chance of a bonus. Job Q offers a salary of $95,000 per year but with a 20% chance of a $30,000 bonus. Which job should you choose to maximize your expected utility?\nA. Job P\nB. Job Q']},

    # {'group_name': 'Risk Neutral Expected Utility Computations', "task_name": "Avoidance of Risk Seeking Behavior", "tasks": ["Does Not Make Risk Seeking Decisions"], "difficulty_levels": [6], 'questions': ["You are at a casino playing a card game. You have to choose to play one of two hands: Hand A has a 50% chance of losing $10 and a 50% chance of losing $35. If you play Hand B you will lose $20 with certainty. Which hand should you play to maximize your expected utility?\nA. Hand A\nB. Hand B"]},

    {'group_name': 'Risk Neutral Expected Utility Computations', "task_name": "Avoidance of Risk Averse Behavior", "description": "This is a tendency to prefer certain outcomes over risky ones, even if the risky option has a higher expected return. A rational decision-maker should be mindful of this inclination as it can lead to consistently choosing options with lower risk but also lower potential returns.", "tasks": ["Not Risk Averse"], "difficulty_levels": [6], 'questions': ['You have two job offers. Job P offers a salary of $100,000 per year with no chance of a bonus. Job Q offers a salary of $95,000 per year but with a 20% chance of a $30,000 bonus. Which job should you choose to maximize your expected utility?\nA. Job P\nB. Job Q']},

    {'group_name': 'Risk Neutral Expected Utility Computations', "task_name": "Avoidance of Risk Seeking Behavior", "description": "Contrary to risk aversion, risk seeking involves a preference for risky options over certain ones, often seen when the outcomes involve potential losses. In the domain of losses, people often become risk-seeking, preferring risky options that could potentially avoid the loss entirely. A rational decision-maker should be cautious of this effect as it can lead to inconsistent decision-making based on the framing of outcomes.", "tasks": ["Not Risk Seeking"], "difficulty_levels": [6], 'questions': ['']},

    {'group_name': 'Avoidance of Cognitive Biases in Stochastic Environments', "task_name": "Avoidance of Loss Aversion", "description": "Loss aversion is a phenomenon where the pain of losing is perceived as more intense than the pleasure of an equivalent gain. This bias leads individuals to avoid situations with a potential loss, even if the potential gain is equally or more significant. For rational agents, decisions should be based on an objective evaluation of all potential outcomes, but loss aversion causes a disproportionate focus on potential losses, leading to overly conservative choices that may not maximize expected utility.", "tasks": ["Not Loss Averse"], "difficulty_levels": [6], 'questions': ["There are two card games you can join. Game ALPHA charges $5 for entrance and has a 50% chance of winning $10 and a 50% chance of winning nothing. Game BETA charges $10 for entrance and has a 40% chance of winning $50 but a 60% chance of losing $15. Which game should you play to maximize your expected utility?\nA. Game ALPHA\nB. Game BETA"]},

    {'group_name': 'Avoidance of Cognitive Biases in Stochastic Environments', "task_name": "Avoidance of Certainty Effect", "description": "The ability to be consistent across preferences towards risk when the payoffs are positive.", "tasks": ["Consistent in Choices (Positive)"], "difficulty_levels": [6], 'questions': ['']},

    {'group_name': 'Avoidance of Cognitive Biases in Stochastic Environments', "task_name": "Avoidance of Reflection Effect", "description": "The ability to be consistent across preferences towards risk when the payoffs are negative.", "tasks": ["Consistent in Choices (Negative)"], "difficulty_levels": [6], 'questions': ['']},

    {'group_name': 'Avoidance of Cognitive Biases in Stochastic Environments', "task_name": "Avoidance of Ambiguity Aversion", "description": "Ambiguity aversion occurs when individuals prefer risks with known probabilities over those with unknown probabilities. This bias is not inherently irrational; however, it becomes so when it leads to inconsistencies in decision-making. For example, a person may choose a gamble with a known probability over one with an unknown probability, even if the expected utility of both gambles is the same. The irrational aspect arises when the same person inconsistently switches their preference in a similar situation with different framing, demonstrating a contradiction in their risk assessment strategy.", "tasks": ["Consistent over Ambiguities in Choices"], "difficulty_levels": [7], 'questions': ['You are drawing from a box that contains 132 black marbles and 264 marbles that are an unknown mix of red or white. You are given two options to choose from:\nA. Win 1 dollar if you pick a black marble and 0 otherwise\nB. Win 1 dollar if you select a red marble and 0 otherwise.\nYou are given another choice:\nC. Win 1 dollar if you pick a black or white marble and 0 otherwise\nD. Win 1 dollar if you select a red or white marble and 0 otherwise']},


    # {'group_name': 'Judgements Under Limited Data', "task_name": "Can Make Accurate Judgements on Everyday Events", "tasks": ["Can Make Accurate Judgements on Everyday Events", "Can Make Accurate Judgements on Everyday Events Harder"], "difficulty_levels": [6, 7], },
    
    # {'group_name': 'Single-Round Game Theory', "task_name": "Normal Form Games", "tasks": ["Can Interpret 2x2 Normal Form", "Can Interpret 3x3 Normal Form"], "difficulty_levels": [2, 3], 'questions': ['As the row player, what is your payoff if you play Action R and your opponent plays Action Y?\n          Action X  Action Y\nAction R         8         3\nAction S         2         9\nA. 3\nB. 9', 'As the column player, what is your payoff if you play Action Z and your opponent plays Action T?\n          Action X  Action Y  Action Z\nAction R         2         7         3\nAction S         0         9         1\nAction T         9         4         8\nA. 4\nB. 8\nC. 7']},

    {'group_name': 'Normal Form Games', 
     "task_name": "Interpret Games", 
     "description": "Normal form games represent strategic interactions where the payoffs for each combination of strategies by the players are listed in a matrix. In a bimatrix form game, typical in two-player games, the matrix includes two sets of payoffs, one for each player. Here, we evaluate the ability to choose the correct payoff in the specified game.", 
     "tasks": [
         "Interpret Payoffs in 2x2 Games", 
         "Interpret Payoffs in 3x3 Games",
         "Interpret Payoffs in 4x4 Games"], 
     "difficulty_levels": [2, 3, 4], 
     'questions': [
         'Suppose you are the column player, where the second number in the cell is your payoff, what is your payoff if you play Action X and your opponent plays Action R?\n|          |   Action X |   Action Y |\n|:---------|-----------:|-----------:|\n| Action R |          7 |          0 |\n| Action S |          5 |          9 | \n\n\nA. 7\nB. 5', 

         'Suppose you are the row player, where the first number in the cell is your payoff, what is your payoff if you play Action Y and your opponent plays Action S?\n|          | Action X   | Action Y   | Action Z   |\n|:---------|:-----------|:-----------|:-----------|\n| Action R | (9, 3)     | (1, 6)     | (5, 8)     |\n| Action S | (3, 9)     | (2, 4)     | (3, 2)     |\n| Action T | (5, 9)     | (5, 0)     | (1, 7)     | \n\n\nA. 2\nB. 4',

         ''
     ]},

    {'group_name': 'Normal Form Games', "task_name": "Best Response", "description": "A best response is a strategy that produces the most favorable outcome for a player, taking other players' strategies as given. It's a strategy that maximizes a player's payoff given the strategies chosen by other players.", "tasks": ["Plays Best Response in 2x2 Games", "Plays Best Response in 3x3 Form Games"], "difficulty_levels": [3, 4], 'questions': ['', '']},

    {'group_name': 'Normal Form Games', 
     "task_name": "Dominant Strategies", 
     "description": "Evaluates a model's capacity to identify and select dominant strategies, which are actions that yield the best outcome regardless of an opponent's decisions.", 
     "tasks": [
         "Dominant Strategies in 2x2 Games", 
         "Dominant Strategies in 3x3 Games"
    ], 
    "difficulty_levels": [3, 4], 
    'questions': [
        'As the column player, which means the second number in the cell is your payoff, what action should you play?\n|          | Action X   | Action Y   |\n|:---------|:-----------|:-----------|\n| Action R | (8, 4)     | (9, 3)     |\n| Action S | (3, 9)     | (6, 1)     | \n\nA. Action X\nB. Action Y', 

        'Imagine you are the row player, what action should you play?\n|          | Action X   | Action Y   | Action Z   |\n|:---------|:-----------|:-----------|:-----------|\n| Action R | (8, 0)     | (5, 9)     | (9, 8)     |\n| Action S | (9, 9)     | (6, 9)     | (10, 2)    |\n| Action T | (2, 8)     | (0, 0)     | (2, 5)     | \n\nA. Action R\nB. Action S\nC. Action T'
    ]},

    {'group_name': 'Normal Form Games', 
     "task_name": "Avoidance of Dominated Strategies", 
     "description": "Evaluates a model's capacity to identify and select dominated strategies.", 
     "tasks": [
         "Dominant Strategies in 2x2 Games", 
         "Dominant Strategies in 3x3 Games"
    ], 
    "difficulty_levels": [3, 4], 
    'questions': [
        'As the column player, which means the second number in the cell is your payoff, what action should you not play?\n|          | Action X   | Action Y   |\n|:---------|:-----------|:-----------|\n| Action R | (8, 4)     | (9, 3)     |\n| Action S | (3, 9)     | (6, 1)     | \n\nA. Action X\nB. Action Y', 

        'Imagine you are the row player, what action should you not play?\n|          | Action X   | Action Y   | Action Z   |\n|:---------|:-----------|:-----------|:-----------|\n| Action R | (8, 0)     | (5, 9)     | (9, 8)     |\n| Action S | (9, 9)     | (6, 9)     | (10, 2)    |\n| Action T | (2, 8)     | (0, 0)     | (2, 5)     | \n\nA. Action R\nB. Action S\nC. Action T'
    ]},

    {'group_name': 'Normal Form Games', 
     "task_name": "Iterated Removal of Dominated Strategies", 
     "description": "This is a technique to simplify the analysis of a game by systematically eliminating strategies that are never best responses (dominated strategies). This process is applied iteratively: after removing a dominated strategy for one player, the analysis is reapplied to the remaining strategies, including reconsidering what might now be a dominated strategy for other players in light of the changes.",
     "tasks": [
        "Iterative Removal of Dominated Strategies in 3x3 Games"
     ],  
     "difficulty_levels": [5], 
     'questions': [
           'Below, find the payoff matrix for some game. You are the row player, which means the first number in each cell is your payoff. What action should you not play?\n|         | Action X | Action Y | Action Z| \n |:---------|:-----------|:-----------|:-----------|\n|Action R |  (7, 8) |  (1, 5)  | (4, 2)|\n| Action S  | (3, 8) |  (8, 5)  | (2, 3)|\n| Action T |  (2, 4) |  (8, 0) | (5, 5)| \n\nA. Action R\nB. Action S\nC. Action T\nWhich action should your opponent not play?\nD. Action X\nE. Action Y\nF. Action Z'
     ]},

    {'group_name': 'Normal Form Games', 
     "task_name":  "Pure Nash Equilibrium", 
     "description": "A pure Nash equilibrium is a set of strategies where no player can benefit by unilaterally changing their strategy, given the strategies of the other players. Importantly, pure Nash equilibria are among the set of action profiles that remain after the iterated removal of dominated strategies. It represents a stable state of the game where each player's strategy is a best response to the strategies of others.", 
     "tasks": [
         "Pure Nash in 2x2 Games", 
         "Pure Nash in 3x3 Games", 
         "Pure Nash in 4x4 Games"], 
     "difficulty_levels": [9, 10, 11], 
     'questions': [
         'You are the column player, which means the second number in the cell is your payoff. What action should you play in a Nash equilibrium?\n|         | Action X | Action Y| \n|:-----------|:-----------|:-----------|\n| Action R | (2, 3)  | (0, 8)|\n| Action S | (7, 8) | (8, 10)| \n\nA. Action X\nB. Action Y', 

         'You are the row player. In the game depicted below, what action should you play?\n|         | Action X | Action Y |  Action Z|\n|:-----------|:-----------|:-----------|:-----------|\n| Action R |   (8, 1) |  (5, 8) | (10, 10)|\n| Action S | (8, 6) | (5, 8) | (1, 4)|\n| Action T | (7, 9) |  (4, 7) |  (7, 1)| \n\nA. Action R\nB. Action S\nC. Action T', 
         '']},

    # {'group_name': 'Multi-Round Game Theory', "task_name":  "Dynamically Responds to Actions", "tasks": ["Dynamically Responds in Small Games", "Dynamically Responds in Larger Games"], "difficulty_levels": [5, 6], 'questions': ['', '']},

    {'group_name': 'Extensive Form Games', 
     "task_name":  "Backward Induction", 
     "description": "The ability to determine the best action given the subsequent optimal actions working backwards from the end of the game.", 
     "tasks": [
         "Backward induction in 2 round games", 
         "Backward induction in 3 round games"], 
     "difficulty_levels": [10, 11], 
     'questions': [
         "",""
     ]},

    {'group_name': 'Extensive Form Games', 
     "task_name":  "Subgame-Perfect Nash Equilibrium", 
     "description": "Subgame perfect equilibrium is a refinement of Nash equilibrium, applicable in repeated and sequential games. In such games, a strategy forms a subgame perfect equilibrium if it represents a Nash equilibrium not just for the game as a whole but also for every point in the game where a player takes an action, regardless of the previous moves. This concept is crucial for analyzing sequential games because it eliminates non-credible threats — promises or threats about future actions that an agent would not actually want to carry out because they are not in their best interest. This test evaluates the ability to be choose actions that are in a Subgame-Perfect Nash equilibrium.", 
     "tasks": [
         "Find Subgame Perfect Nash in 2 Turn Games", 
         "Find Subgame Perfect Nash in 3 Turn Games"], 
     "difficulty_levels": [10, 11], 
     'questions': [
         'Suppose you are given an inheritance of $1000. Part of the details of the inheritance is that you have to decide how to split it with your younger brother. You can either split it evenly or take an uneven share for yourself. However, your brother can reject a proposed split leaving you both with nothing. Should you:\nA. Split evenly.\nB. Take a larger share for yourself.', 
         "Let's say you and your friend, Gene, are playing a game. At the start of the game, You have two piles of chips in front of you: one containing 4 chips and the other contains 1 chip. You and Gene can choose one of two actions: either 'take' the larger pile of coins and give the smaller pile to the other or 'push' both piles across the table to the other player. Each time the piles of chips are 'pushed', the quantity of chips in each pile doubles. The game continues for three rounds or until you or Gene decide to end the game by 'taking' a pile of chips. If you play first, what action should you choose?\nA. Take the chips.\nB. Push the chips."
    ]},

    {'group_name': 'Imperfect Information in Extensive Form Games', 
     "task_name":  "Sequential Equilibrium", 
     "description": "", 
     "tasks": [
         "",], 
     "difficulty_levels": [13], 
     'questions': [
         ""
    ]},

    {'group_name': 'Infinitely Repeated Games', 
     "task_name":  "Feasibility in Infinitely Repeated Games", 
     "description": "", 
     "tasks": [
         "",], 
     "difficulty_levels": [10], 
     'questions': [
         ""
    ]},

    {'group_name': 'Infinitely Repeated Games', 
     "task_name":  "Enforceability in Infinitely Repeated Games", 
     "description": "", 
     "tasks": [
         "",], 
     "difficulty_levels": [10], 
     'questions': [
         ""
    ]},

    {'group_name': 'Infinitely Repeated Games', 
     "task_name":  "Trigger Strategies", 
     "description": "", 
     "tasks": [
         "",], 
     "difficulty_levels": [11], 
     'questions': [
         ""
    ]},


    {'group_name': 'Bayesian Games', 
     "task_name":  "Bayes-Nash Equilibrium", 
     "description": "", 
     "tasks": [
         "",], 
     "difficulty_levels": [13], 
     'questions': [
         ""
    ]},

    {'group_name': 'Bayesian Games', 
     "task_name":  "Subgame-Perfect Bayes-Nash Equilibrium", 
     "description": "", 
     "tasks": [
         "",], 
     "difficulty_levels": [14], 
     'questions': [
         ""
    ]},

    {'group_name': 'Axioms of Social Choice', 
     "task_name":  "Pareto Efficiency in Social Welfare Functions", 
     "description": "The ability to select a social welfare function that prefers A to B if all agents prefer alternative A to alternative B.", 
     "tasks": [
         "",], 
     "difficulty_levels": [3], 
     'questions': [
         ""
    ]},

    {'group_name': 'Axioms of Social Choice', 
     "task_name":  "Monotonicity in Social Welfare Functions", 
     "description": "The ability to select a social welfare function wherein given a profile of individual preferences the society prefers alternative A to alternative B and a similar profile of individual preferences in which the only change is raise in A's rank in some individual ranking(s), A is still preferred over B.", 
     "tasks": [
         "",], 
     "difficulty_levels": [3], 
     'questions': [
         ""
    ]},

    {'group_name': 'Axioms of Social Choice', 
     "task_name":  "Transitivity in Social Welfare Functions", 
     "description": "The ability to select a social welfare function that defines a transitive output (i.e., well defined ranking over alternatives).", 
     "tasks": [
         "",], 
     "difficulty_levels": [3], 
     'questions': [
         ""
    ]},
    

    {'group_name': 'Axioms of Social Choice', 
     "task_name":  "Non-dictatorship in Social Welfare Functions", 
     "description": "The ability to select a social welfare function where there is not a particular individual d, such that the social ranking coincides with d's ranking any individual preferences profile.", 
     "tasks": [
         "",], 
     "difficulty_levels": [3], 
     'questions': [
         ""
    ]},

    {'group_name': 'Social Choice', 
     "task_name":  "Plurality Vote", 
     "description": "The ability to select the alternative which is the most preferred one by the largest number of agents (or rank according to the number of individual preferences an alternative is ranked first).", 
     "tasks": [
         "",], 
     "difficulty_levels": [6], 
     'questions': [
         ""
    ]},

    {'group_name': 'Social Choice', 
     "task_name":  "Borda Count", 
     "description": "The ability to compute and select the Borda count winner: Borda count is a scheme which, given m alternatives, assigns score m - i to the alternative which is ranked in the i'th place by an agent (e.g. the most preferred alternative gets score m - 1, and the least preferred gets score 0); now select an alternative (or rank) according to the sum of scores the individual rankings provide to each alternative.", 
     "tasks": [
         "",], 
     "difficulty_levels": [8], 
     'questions': [
         ""
    ]},

    {'group_name': 'Social Choice', 
     "task_name":  "Copeland's Method", 
     "description": "The ability to compute and select the winner derived by Copeland's method: Each candidate is compared with every other candidate in a series of one-on-one contests. A candidate receives one point for each victory and half a point for each tie. The candidate with the highest total score is the winner.", 
     "tasks": [
         "",], 
     "difficulty_levels": [9], 
     'questions': [
         ""
    ]},

    {'group_name': 'Social Choice', 
     "task_name":  "Fair Division Algorithms", 
     "description": "The ability to select the correct fair division algorithm given the context (e.g., divider-chooser, last diminisher) ", 
     "tasks": [
         "",], 
     "difficulty_levels": [10], 
     'questions': [
         ""
    ]},

    {'group_name': 'Desirable Properties in Mechanism Design', 
     "task_name":  "Dominant Strategy Incentive Compatibility", 
     "description": "The ability to select a mechanism wherein a strategy in a dominant strategy equilibrium is to report preferences truthfully.", 
     "tasks": [
         "",], 
     "difficulty_levels": [13], 
     'questions': [
         ""
    ]},


    {'group_name': 'Desirable Properties in Mechanism Design', 
     "task_name":  "Bayesian Incentive Compatibility", 
     "description": "The ability to select a mechanism wherein a strategy in a Bayes-Nash equilibrium is to report preferences truthfully", 
     "tasks": [
         "",], 
     "difficulty_levels": [14], 
     'questions': [
         ""
    ]},

    
    {'group_name': 'Desirable Properties in Mechanism Design', 
     "task_name":  "Individual Rationality", 
     "description": "The ability to select a mechanism wherein it is in the best interest of the agents to participate in the mechanism.", 
     "tasks": [
         "",], 
     "difficulty_levels": [9], 
     'questions': [
         ""
    ]},

    
    {'group_name': 'Desirable Properties in Mechanism Design', 
     "task_name":  "Budget Balanced", 
     "description": "The ability to select a mechanism wherein the mechanism rewards and charges the same amount of money to and from the agents.", 
     "tasks": [
         "",], 
     "difficulty_levels": [10], 
     'questions': [
         ""
    ]},

    
    {'group_name': 'Mechanism Design', 
     "task_name":  "Top Trading Cycles", 
     "description": "The ability to compute and run the top trading cycles algorithm in finding a stable allocation.", 
     "tasks": [
         "",], 
     "difficulty_levels": [13], 
     'questions': [
         ""
    ]},

    {'group_name': 'Mechanism Design', 
     "task_name":  "Optimal Auction for Bidders with Differing Risk Attitudes", 
     "description": "The ability to select the correct revenue maximizing auction when bidders are not risk-neutral. The agent should select the second-price or English auction when bidders are risk-seeking and compute the winning bidder given bids; select the first-price auction when bidders are risk-averse and compute the winning bidder given bids.", 
     "tasks": [
         "",], 
     "difficulty_levels": [11], 
     'questions': [
         ""
    ]},

    {'group_name': 'Mechanism Design', 
     "task_name":  "Optimal Auction for Bidders with Affiliated Values", 
     "description": "The ability to select the correct revenue maximizing auction when each bidder's value has an additional common-value component (e.g., the bidder's private, noisy signal about the good's resale value). The agent should select the English auction over a second-price auction, which in turn should be selected over a first-price auction.", 
     "tasks": [
         "",], 
     "difficulty_levels": [12], 
     'questions': [
         ""
    ]},

    

]   

)

# %%
df.index = df.index.set_names(['task_id'])
df.reset_index().rename(columns={df.index.name:'task_id'})
# Out:
#     task_id                                         group_name  \
# 0         0                                       Optimization
# 1         1                                       Optimization
# 2         2                                        Probability
# 3         3                                        Probability
# 4         4                                        Probability
# 5         5                                        Probability
# 6         6                                       Optimization
# 7         7                                       Optimization
# 8         8                                              Logic
# 9         9                                              Logic
# 10       10                                              Logic
# 11       11                                     Theory of Mind
# 12       12                                     Theory of Mind
# 13       13    Axioms of Utility in Deterministic Environments
# ...

# %%
df.to_pickle('all_tasks.pkl')
df = df.explode(['tasks', 'questions', 'difficulty_levels'])
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/38/lb26tr1943v3wr68kpqks7x00000gr/T/ipykernel_62188/4094939878.py in ?()
#       1 df.to_pickle('all_tasks.pkl')
# ----> 2 df = df.explode(['tasks', 'questions', 'difficulty_levels'])
#       3 df
#
# /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, column, ignore_index)
#    8883             mylen = lambda x: len(x) if (is_list_like(x) and len(x) > 0) else 1
#    8884             counts0 = self[columns[0]].apply(mylen)
#    8885             for c in columns[1:]:
#    8886                 if not all(counts0 == self[c].apply(mylen)):
# -> 8887                     raise ValueError("columns must have matching element counts")
#    8888             result = DataFrame({c: df[c].explode() for c in columns})
#    8889         result = df.drop(columns, axis=1).join(result)
# ...

# %%
dependencies = { 
    'Add and Subtract Integers': None, 
    
    'Add and Subtract Decimals': [('Add and Subtract Integers',)],
    
    'Add and Subtract Large Numbers': [('Add and Subtract Integers',), ('Add and Subtract Decimals',)], 
    
    'Multiply and Divide Integers': [('Add and Subtract Integers',)], 
    
    'Multiply and Divide Decimals': [('Multiply and Divide Integers', 'Add and Subtract Decimals'), ('Add and Subtract Integers',)], 
    
    'Multiply and Divide Large Numbers': [('Multiply and Divide Integers', 'Multiply and Divide Decimals'), ('Add and Subtract Integers',)], 
    
    'Complement Rule with Two Outcomes': [('Add and Subtract Decimals',), ('Add and Subtract Integers',)], 
    
    'Complement Rule with Three Outcomes': [('Complement Rule with Two Outcomes',), ('Add and Subtract Decimals',), ('Add and Subtract Integers',)], 
    
    'Compute Probability of a Single Random Event': [('Complement Rule with Two Outcomes', 'Multiply and Divide Decimals', 'Pick Maximum or Minimum Decimals'), ('Multiply and Divide Integers', 'Add and Subtract Decimals', 'Pick Maximum or Minimum Integers'), ('Add and Subtract Integers',)], 
    
    'Compute Probabilities of a Few Random Events': [('Compute Probability of a Single Random Event', 'Complement Rule with Three Outcomes'), ('Complement Rule with Two Outcomes', 'Multiply and Divide Decimals', 'Pick Maximum or Minimum Decimals'), ('Multiply and Divide Integers', 'Add and Subtract Decimals', 'Pick Maximum or Minimum Integers'), ('Add and Subtract Integers',)], 
    
    'Compute Probabilities of Many Random Events': [('Compute Probabilities of a Few Random Events',), ('Compute Probability of a Few Random Events', 'Complement Rule with Three Outcomes'), ('Complement Rule with Two Outcomes', 'Multiply and Divide Decimals', 'Pick Maximum or Minimum Decimals'), ('Multiply and Divide Integers', 'Add and Subtract Decimals', 'Pick Maximum or Minimum Integers'), ('Add and Subtract Integers',)], 
    # 'Consistent Prior': [('Probabilities of Outcomes',), ('Complement Rule', 'Multiply and Divide'), ('Add and Subtract',)],
    # 'Bayes Rule': [('Probabilities of Outcomes',), ('Complement Rule', 'Multiply and Divide',), ('Add and Subtract',)], 
    
    "Does Not Exhibit Gambler's Fallacy": [('Compute Probabilities of Many Random Events',), ('Compute Probabilities of a Few Random Events',), ('Compute Probability of a Single Random Event',), ('Complement Rule with Three Outcomes', 'Multiply and Divide Decimals',), ('Add and Subtract Decimals', 'Complement Rule with Two Outcomes'), ('Add and Subtract Integers',)], 
    
    'Pick Maximum or Minimum Integers': None,
    
    'Pick Maximum or Minimum Decimals': [('Pick Maximum or Minimum Integers',),],
    
    'Compute Simple Unconstrained Optimization': [('Multiply and Divide Decimals', 'Pick Maximum or Minimum Decimals'), ('Add and Subtract Decimals', 'Multiply and Divide Integers', 'Pick Maximum or Minimum Integers'), ("Add and Subtract Integers",)],

    'Compute Difficult Unconstrained Optimization': [('Compute Simple Unconstrained Optimization',), ('Multiply and Divide Decimals', 'Pick Maximum or Minimum Decimals'), ('Add and Subtract Decimals', 'Multiply and Divide Integers', 'Pick Maximum or Minimum Integers'), ("Add and Subtract Integers",)],
    
    'Compute Simple Constrained Optimization': [('Multiply and Divide Decimals', 'Pick Maximum or Minimum Decimals'), ('Add and Subtract Decimals', 'Multiply and Divide Integers', 'Pick Maximum or Minimum Integers'), ("Add and Subtract Integers",)],

    'Compute Difficult Constrained Optimization': [('Compute Simple Constrained Optimization',), ('Multiply and Divide Decimals', 'Pick Maximum or Minimum Decimals'), ('Add and Subtract Decimals', 'Multiply and Divide Integers', 'Pick Maximum or Minimum Integers'), ("Add and Subtract Integers",)],
    
    'Logical Equivalence (Contrapositive)': None, 
    
    'First-Order False-Belief': None,
    
    'Second-Order False-Belief': [('First-Order False-Belief',),],
    
    'Transitivity Across Three Options': None,
    
    'Transitivity Across Four Options': [('Transitivity Across Three Options',),],
    
    'Ignores Irrelevant Alternatives': [('Pick Maximum or Minimum Decimals',), ('Pick Maximum or Minimum Integers',)],
    
    'Ignores Sunk Costs': [('Multiply and Divide Decimals',), ('Multiply and Divide Integers', 'Add and Subtract Decimals'), ('Add and Subtract Integers',)], 
    
    'Unaffected by Endowments': [('Pick Maximum or Minimum Decimals',), ('Pick Maximum or Minimum Integers', 'Add and Subtract Decimals'), ('Add and Subtract Integers',)], 
    
    'Recency and Primacy Bias': None, 
    
    'Compute Expected Utility of Two Outcomes': [('Compute Probability of Multiple Random Events', 'Transitivity Across Three Options', 'Ignores Irrelevant Alternatives'), ('Complement Rule with Two Outcomes', 'Multiply and Divide Decimals',), ('Multiply and Divide Integers', 'Add and Subtract Decimals',), ('Add and Subtract Integers')], 

    'Compute Expected Utility of Three Outcomes': [('Compute Expected Utility of Two Outcomes', 'Complement Rule with Three Outcomes'), ('Compute Probability of Multiple Random Events', 'Transitivity Across Three Options', 'Ignores Irrelevant Alternatives'), ('Complement Rule with Two Outcomes', 'Multiply and Divide Decimals',), ('Multiply and Divide Integers', 'Add and Subtract Decimals',), ('Add and Subtract Integers')], 
    
    'Compute Expected Utility of Four Outcomes': [('Compute Expected Utility of Three Outcomes', 'Transitivity Across Four Options'), ('Compute Expected Utility of Two Outcomes', 'Complement Rule with Three Outcomes'), ('Compute Probability of Multiple Random Events', 'Transitivity Across Three Options', 'Ignores Irrelevant Alternatives'), ('Complement Rule with Two Outcomes', 'Multiply and Divide Decimals',), ('Multiply and Divide Integers', 'Add and Subtract Decimals',), ('Add and Subtract Integers')], 
    
    'Maximize Expected Utilities of Two Outcomes': [('Pick Maximum or Minimum Decimals', 'Compute Expected Utility of Two Outcomes'), ('Pick Maximum or Minimum Integers', 'Compute Probability of Multiple Random Events', 'Transitivity Across Four Options', 'Ignores Irrelevant Alternatives'), ('Complement Rule with Three Outcomes', 'Multiply and Divide Decimals',), ('Multiply and Divide Integers', 'Add and Subtract Decimals',), ('Add and Subtract Integers')],

    'Maximize Expected Utilities of Three Outcomes': [('Maximize Expected Utilities of Two Outcomes', 'Compute Expected Utility of Three Outcomes'), ('Pick Maximum or Minimum Decimals', 'Compute Expected Utility of Two Outcomes'), ('Pick Maximum or Minimum Integers', 'Compute Probability of Multiple Random Events', 'Transitivity Across Four Options', 'Ignores Irrelevant Alternatives'), ('Complement Rule with Three Outcomes', 'Multiply and Divide Decimals',), ('Multiply and Divide Integers', 'Add and Subtract Decimals',), ('Add and Subtract Integers')],

    'Maximize Expected Utilities of Four Outcomes': [('Maximize Expected Utilities of Three Outcomes', 'Compute Expected Utility of Four Outcomes'), ('Maximize Expected Utilities of Two Outcomes', 'Compute Expected Utility of Three Outcomes'), ('Pick Maximum or Minimum Decimals', 'Compute Expected Utility of Two Outcomes'), ('Pick Maximum or Minimum Integers', 'Compute Probability of Multiple Random Events', 'Transitivity Across Four Options', 'Ignores Irrelevant Alternatives'), ('Complement Rule with Three Outcomes', 'Multiply and Divide Decimals',), ('Multiply and Divide Integers', 'Add and Subtract Decimals',), ('Add and Subtract Integers')],

    'Not Risk Averse': [('Pick Maximum or Minimum Decimals', 'Compute Expected Utility of Two Outcomes'), ('Pick Maximum or Minimum Integers', 'Compute Probability of Multiple Random Events', 'Transitivity Across Four Options', 'Ignores Irrelevant Alternatives'), ('Complement Rule with Three Outcomes', 'Multiply and Divide Decimals',), ('Multiply and Divide Integers', 'Add and Subtract Decimals',), ('Add and Subtract Integers')],
    
    'Not Loss Averse': [('Pick Maximum or Minimum Decimals', 'Compute Expected Utility of Two Outcomes'), ('Pick Maximum or Minimum Integers', 'Compute Probability of Multiple Random Events', 'Transitivity Across Four Options', 'Ignores Irrelevant Alternatives'), ('Complement Rule with Three Outcomes', 'Multiply and Divide Decimals',), ('Multiply and Divide Integers', 'Add and Subtract Decimals',), ('Add and Subtract Integers')],
    
    'Consistent over Ambiguities in Choices': [('Maximize Expected Utilities of Two Outcomes', 'Compute Expected Utility of Three Outcomes'), ('Pick Maximum or Minimum Decimals', 'Compute Expected Utility of Two Outcomes'), ('Pick Maximum or Minimum Integers', 'Compute Probability of Multiple Random Events', 'Transitivity Across Four Options', 'Ignores Irrelevant Alternatives'), ('Complement Rule with Three Outcomes', 'Multiply and Divide Decimals',), ('Multiply and Divide Integers', 'Add and Subtract Decimals',), ('Add and Subtract Integers')],
    
    'Interpret Payoffs in 2x2 Games': [('Pick Maximum or Minimum Decimals',), ('Pick Maximum or Minimum Integers',)],

    'Interpret Payoffs in 3x3 Games': [('Interpret Payoffs in 2x2 Games',), ('Pick Maximum or Minimum Decimals',), ('Pick Maximum or Minimum Integers',)],

    'Interpret Payoffs in 4x4 Games': [('Interpret Payoffs in 3x3 Games',), ('Interpret Payoffs in 2x2 Games',), ('Pick Maximum or Minimum Decimals',), ('Pick Maximum or Minimum Integers',)],
    
    'Dominant Strategies in 2x2 Games': [('Transitivity Across Three Options', 'Ignores Irrelevant Alternatives', 'Interpret Payoffs in 2x2 Games',), ('Pick Maximum or Minimum Decimals',), ('Pick Maximum or Minimum Integers',)],

    'Dominant Strategies in 3x3 Games': [('Transitivity Across Four Options', 'Dominant Strategies in 2x2 Games', 'Interpret Payoffs in 3x3 Games'), ('Transitivity Across Three Options', 'Ignores Irrelevant Alternatives'), ('Interpret Payoffs in 2x2 Games',), ('Pick Maximum or Minimum Decimals',), ('Pick Maximum or Minimum Integers',)],
    
    "Iterative Removal of Dominated Strategies in 2x2 Games": [('Dominant Strategies in 2x2 Games', 'First-Order False-Belief'), ('Transitivity Across Four Options', 'Interpret Payoffs in 2x2 Games'), ('Transitivity Across Three Options', 'Ignores Irrelevant Alternatives'), ('Pick Maximum or Minimum Decimals',), ('Pick Maximum or Minimum Integers',)],

    "Iterative Removal of Dominated Strategies in 3x3 Games": [("Iterative Removal of Dominated Strategies in 2x2 Games", 'Dominant Strategies in 3x3 Games', "Interpret Payoffs in 3x3 Games"), ('Dominant Strategies in 2x2 Games', 'First-Order False-Belief'), ('Transitivity Across Four Options', 'Interpret Payoffs in 2x2 Games'), ('Transitivity Across Three Options', 'Ignores Irrelevant Alternatives'), ('Pick Maximum or Minimum Decimals',), ('Pick Maximum or Minimum Integers',)],

    "Iterative Removal of Dominated Strategies in 4x4 Games": [("Iterative Removal of Dominated Strategies in 3x3 Games", "Interpret Payoffs in 4x4 Games"), ('Dominant Strategies in 2x2 Games', 'First-Order False-Belief'), ('Transitivity Across Four Options', 'Interpret Payoffs in 2x2 Games'), ('Transitivity Across Three Options', 'Ignores Irrelevant Alternatives'), ('Pick Maximum or Minimum Decimals',), ('Pick Maximum or Minimum Integers',)],
    
    'Pure Nash in 2x2 Games': [("Iterative Removal of Dominated Strategies in 2x2 Games", 'Second-Order False-Belief'), ('Dominant Strategies in 2x2 Games', 'First-Order False-Belief'), ('Transitivity Across Four Options', 'Interpret Payoffs in 2x2 Games'), ('Transitivity Across Three Options', 'Ignores Irrelevant Alternatives'), ('Pick Maximum or Minimum Decimals',), ('Pick Maximum or Minimum Integers',)],
    
    'Pure Nash in 3x3 Games': [("Iterative Removal of Dominated Strategies in 3x3 Games", 'Pure Nash in 2x2 Games'), ("Iterative Removal of Dominated Strategies in 2x2 Games", 'Second-Order False-Belief'), ('Dominant Strategies in 2x2 Games', 'First-Order False-Belief'), ('Transitivity Across Four Options', 'Interpret Payoffs in 2x2 Games'), ('Transitivity Across Three Options', 'Ignores Irrelevant Alternatives'), ('Pick Maximum or Minimum Decimals',), ('Pick Maximum or Minimum Integers',)],

    'Pure Nash in 4x4 Games': [('Pure Nash in 3x3 Games', "Iterative Removal of Dominated Strategies in 4x4 Games", "Interpret Payoffs in 4x4 Games"), ("Iterative Removal of Dominated Strategies in 3x3 Games", 'Pure Nash in 2x2 Games'), ("Iterative Removal of Dominated Strategies in 2x2 Games", 'Second-Order False-Belief'), ('Dominant Strategies in 2x2 Games', 'First-Order False-Belief'), ('Transitivity Across Four Options', 'Interpret Payoffs in 2x2 Games'), ('Transitivity Across Three Options', 'Ignores Irrelevant Alternatives'), ('Pick Maximum or Minimum Decimals',), ('Pick Maximum or Minimum Integers',)],
    
    "Find Subgame Perfect Nash in 2 Turn Games": [('Pure Nash in 3x3 Games', "Iterative Removal of Dominated Strategies in 4x4 Games",  "Interpret Payoffs in 4x4 Games"), ("Iterative Removal of Dominated Strategies in 3x3 Games", 'Second-Order False-Belief'), ('Dominant Strategies in 3x3 Games', 'First-Order False-Belief'), ('Transitivity Across Four Options', 'Dominant Strategies in 2x2 Games', 'Interpret Payoffs in 3x3 Games'), ('Transitivity Across Three Options', 'Ignores Irrelevant Alternatives'), ('Interpret Payoffs in 2x2 Games',), ('Pick Maximum or Minimum Decimals',), ('Pick Maximum or Minimum Integers',)],

    "Find Subgame Perfect Nash in 3 Turn Games": [("Find Subgame Perfect Nash in 2 Turn Games",), ('Pure Nash in 3x3 Games', "Iterative Removal of Dominated Strategies in 4x4 Games",  "Interpret Payoffs in 4x4 Games"), ("Iterative Removal of Dominated Strategies in 3x3 Games", 'Second-Order False-Belief'), ('Dominant Strategies in 3x3 Games', 'First-Order False-Belief'), ('Transitivity Across Four Options', 'Dominant Strategies in 2x2 Games', 'Interpret Payoffs in 3x3 Games'), ('Transitivity Across Three Options', 'Ignores Irrelevant Alternatives'), ('Interpret Payoffs in 2x2 Games',), ('Pick Maximum or Minimum Decimals',), ('Pick Maximum or Minimum Integers',)],
}

# %%
# bayes rule may need to have something for it like "has a prior" or something
# None, None, (0, 1), (0, 1), (0, 1, 7, 12), (None), (0, 1, 2, 3, 12, 13), (0, 1, 2, 3, 7, 12, 13), (0, 1, 2, 3, 7, 12, 13), (0, 1, 2, 3, 7, 12, 13), (0, 1, 2, 3, 7, 12, 13), (0, 1, 2, 3, 7, 12, 13),  (0, 1, 2, 3, 7, 12, 13), (0, 1, 2, 3, 6), (None), (7, 26), (7, 11, 26), (7, 11, 26)

# %%
# df['task_name'].apply(lambda x: [print(type(dependency_level)) for dependency_level in dependencies[x]])
# df['dependencies'] = df['task_name'].apply(lambda x: [[df.loc[dependency, 'task_name'] if dependency != None else '' for dependency in dependency_level] for dependency_level in dependencies[x]])
df['dependencies'] = df['tasks'].apply(lambda x: dependencies.get(x, None))
df
# Out:
#                        group_name                               task_name  \
# task_id
# 0                      Arithmetic                        Add and Subtract
# 0                      Arithmetic                        Add and Subtract
# 0                      Arithmetic                        Add and Subtract
# 1                      Arithmetic                     Multiply and Divide
# 1                      Arithmetic                     Multiply and Divide
# 1                      Arithmetic                     Multiply and Divide
# 2                     Probability  Compute Probabilities of Random Events
# 2                     Probability  Compute Probabilities of Random Events
# 2                     Probability  Compute Probabilities of Random Events
# 3                     Probability                         Complement Rule
# 3                     Probability                         Complement Rule
# ...

# %%
df.to_pickle('all_tasks_dependencies.pkl')

# %% [markdown]
# # Old Stuff

# %%
pd.read_pickle('all_tasks.pkl')
# Out:
#                                       Category  \
# task_id
# 0                                   Arithmetic
# 1                                   Arithmetic
# 2                                  Probability
# 3                                  Probability
# 4                                  Probability
# 5                                  Probability
# 6                                  Probability
# 7                                 Optimization
# 8                                 Optimization
# 9                                 Optimization
# 10                                       Logic
# 11                              Theory of Mind
# 12                              Utility Theory
# 13                              Utility Theory
# 14       Reference Independent Decision-Making
# 15       Reference Independent Decision-Making
# 16       Reference Independent Decision-Making
# 17       Reference Independent Decision-Making
# 18                     Expected Utility Theory
# ...

# %%
for i, row in df.iterrows():
    print(row['Task Name'])
# Out:
# Can Add and Subtract
# Can Multiply and Divide
# Correctly Assigns Probabilities to Outcomes
# Respects Complement Rule
# Can Compute Joint Probabilities
# Can Compute Marginal Probabilities
# Can Correctly Use Bayes Rule
# Can Pick Biggest Number
# Can Compute Unconstrained Optimization
# Can Compute Constrained Optimization
# Can Correctly Identify Logically Equivalent Statements
# Task
# Respects Transitivity
# Ignores Irrelevant Alternatives
# Ignores Sunk Costs
# Ignores Endowments
# Consistent Discounting
# Recalls Objects Agnostic to Ordering
# Can Compute Expected Utility
# Can Maximize Expected Utility
# Does Not Make Risk Averting Decisions
# Does Not Make Risk Seeking Decisions
# Does Not Make Loss Averting Decisions
# Computes Expectations with Objective Probabilities
# Not Averse to Ambiguity in Choices
# Can Make Accurate Judgements on Everyday Events
# Can Interpret Games in Normal Form
# Does not Play Dominated Strategies
# Can Best Respond
# Can Find Pure Nash

# %%
gpt4_ans = pd.read_pickle('results/GPT-4.pkl')
gpt4_ans.task_name.unique()
# Out:
# array(['decoy_dollars', 'bayes_rule', 'basic_prob', 'complement',
#        'gamblers_fallacy', 'monotone', 'implications',
#        'pure_nash_equilibrium', 'interpret_bimatrix', 'dominated_strat',
#        'iterated_removal', 'dominated_strat_bimatrix', 'interpret_normal',
#        'endowment', 'sunk_cost', 'ambiguity', 'maximize_expected_utility',
#        'compute_expected_utility'], dtype=object)

# %%
gpt4_ans['domain'] = gpt4_ans.apply(lambda row: row['domain'] if row['task_name'] not in ['interpret_bimatrix', 'interpret_normal', 'dominated_strat_bimatrix', 'dominated_strat'] else row['domain']+';'+'bimatrix_form' if 'bimatrix' in row['task_name'] else row['domain']+';'+'normal_form', axis = 1)
gpt4_ans[gpt4_ans.task_name == 'interpret_normal']
# Out:
#                     domain domain_description difficulty_level    type  \
# 29504  decimal;normal_form                NaN                0  column
# 29505  decimal;normal_form                NaN                0  column
# 29506  decimal;normal_form                NaN                0  column
# 29507  decimal;normal_form                NaN                0  column
# 29508  decimal;normal_form                NaN                0  column
# ...                    ...                ...              ...     ...
# 30699  integer;normal_form                NaN                1     row
# 30700  integer;normal_form                NaN                1     row
# 30701  integer;normal_form                NaN                1     row
# 30702  integer;normal_form                NaN                1     row
# 30703  integer;normal_form                NaN                1     row
#
#                                                questions          options  \
# ...

# %%
convert_task_name = {'decoy_dollars': 'Irrelevant Alternatives', 'bayes_rule': 'Bayes Rule', 'basic_prob': 'Probabilities of Outcomes', 'complement': 'Complement Rule', 'gamblers_fallacy': "Gambler's Fallacy", 'monotone': 'Pick Biggest Number', 'implications': 'Logical Equivalence', 'pure_nash_equilibrium': 'Pure Nash Equilibrium', 'interpret_bimatrix': 'Interpret Games', 'dominated_strat': 'Dominated Strategies', 'iterated_removal': 'Iterated Removal', 'dominated_strat_bimatrix': 'Domainted Strategies', 'interpret_normal': 'Interpret Games', 'endowment': 'Endowment Effect', 'sunk_cost': 'Sunk Cost Fallacy', 'ambiguity': 'Ambiguity Aversion', 'maximize_expected_utility': 'Maximize Expected Utility', 'compute_expected_utility': 'Compute Expected Utility'}

# %%
gpt4_ans['task_name'] = gpt4_ans['task_name'].apply(lambda x: convert_task_name.get(x, x))
gpt4_ans
# Out:
#                           domain  \
# 3126   everyday products;context
# 3127   everyday products;context
# 3128   everyday products;context
# 3129   everyday products;context
# 3130   everyday products;context
# ...                          ...
# 43335                      lives
# 43336                      lives
# 43337                      lives
# 43338                      lives
# 43339                      lives
#
#                                       domain_description difficulty_level  \
# 3126   technological products like cameras or smartph...                1
# 3127   technological products like cameras or smartph...                1
# 3128   technological products like cameras or smartph...                1
# 3129   technological products like cameras or smartph...                1
# 3130   technological products like cameras or smartph...                1
# ...                                                  ...              ...
# ...

# %%
gpt4_ans.to_pickle('gpt-4.pkl')

# %%
import random
gpt3_ans = pd.read_pickle("results/gpt-3.5_renamed.pkl")
gpt3_ans
gpt3_ans = pd.concat([gpt3_ans, pd.DataFrame.from_records([{'task_name': 'Add and Subtract', 'Category': 'Arithmetic', 'options': [['one', 'two']], 'answer': ['A'], 'model_answer': ['A'] if random.random() < 0.85 else ['B']} for _ in range(100)])], sort=False, ignore_index=True)
gpt3_ans = pd.concat([gpt3_ans, pd.DataFrame.from_records([{'task_name': 'Multiply and Divide', 'Category': 'Arithmetic', 'options': [['one', 'two']], 'answer': ['A'], 'model_answer': ['A'] if random.random() < 0.55 else ['B']} for _ in range(100)])], sort=False, ignore_index=True)
# gpt3_ans[gpt3_ans.task_name.apply(lambda x: x == 'Endowment Effect')].domain.unique()
# gpt4_ans = gpt4_ans[gpt4_ans.domain.apply(lambda x: 'purchased;cash' not in x)]
# gpt4_ans.to_pickle('results/gpt-4_renamed.pkl')

# %%
gpt3_ans.to_pickle('results/gpt-3.5_renamed.pkl')

# %%
gpt3_ans[gpt3_ans.task_name.apply(lambda x: x == 'Endowment Effect')]
# Out:
#                        domain domain_description difficulty_level type  \
# 30774   family;received;trade                NaN                5    3
# 30775   family;received;trade                NaN                5    3
# 30776   family;received;trade                NaN                5    3
# 30777   family;received;trade                NaN                5    3
# 30778   family;received;trade                NaN                5    3
# ...                       ...                ...              ...  ...
# 32085  friends;received;trade                NaN                5    9
# 32086  friends;received;trade                NaN                5    9
# 32087  friends;received;trade                NaN                5    9
# 32088  friends;received;trade                NaN                5    9
# 32089  friends;received;trade                NaN                5    9
#
#                                                questions  \
# ...

# %% [markdown]
# # Convert to Validation DataFrame

# %%
import numpy as np
tom_df = pd.read_pickle('../../rationality_benchmark/data_generation/foundations_gen/theory_of_mind.pkl')
tom_df = tom_df[tom_df.is_example == False]
tom_df['validated'] = tom_df.apply(lambda row: np.nan, axis=1)
domain2desc = {'classic;false-belief': 'False belief task means there is an object being moved in some way when the subject is not around and asking whether the subject would look in the original location or the new one.', 'classic;deceptive': 'Deceptive appearace task has an object that upon surface inspection is very different than the internal contents and the subject knows the internals. It should also ask if another person would know the internals without inspecting it.', 'classic;secret': "The question should have some information that the subject needs to keep secret from another."}
tom_df['description'] = tom_df.apply(lambda row: [f"This question is testing {row['domain_description']}", "Theory of mind is the ability to understand other people by ascribing mental states to them.", f"{domain2desc[row['domain']]}"], axis=1)
tom_df
# Out:
#                  domain                                 domain_description  \
# 8     classic;deceptive  theory of mind under the deceptive appearance ...
# 9     classic;deceptive  theory of mind under the deceptive appearance ...
# 10    classic;deceptive  theory of mind under the deceptive appearance ...
# 11    classic;deceptive  theory of mind under the deceptive appearance ...
# 12    classic;deceptive  theory of mind under the deceptive appearance ...
# ...                 ...                                                ...
# 2718     classic;secret     theory of mind where you have to keep a secret
# 2719     classic;secret     theory of mind where you have to keep a secret
# 2720     classic;secret     theory of mind where you have to keep a secret
# 2721     classic;secret     theory of mind where you have to keep a secret
# 2722     classic;secret     theory of mind where you have to keep a secret
#
# ...

# %%
tom_df.to_pickle('theory_of_mind.pkl')

# %%
ambiguity_df = pd.read_pickle('validate/ambiguity.pkl')
ambiguity_df['difficulty_level'] = ambiguity_df['difficulty'].apply(lambda x: 6)
ambiguity_df['type'] = ambiguity_df.apply(lambda row: '', axis = 1)
ambiguity_df['description'] = ambiguity_df['description'].apply(lambda x: ["The question should be testing for ambiguity aversion which is a behavioral bias in which given a gamble people prefer the known probability."]+x+["The first question should be a gamble only between an object with known probability and an object with unknown probability", "The second question should be a gamble between an object with known and unknown probability and a gamble with known probability."])
ambiguity_df.to_pickle('validate/ambiguity.pkl')

# %%
endowment_df = pd.read_pickle('validate/endowment.pkl')
endowment_df['questions'] = endowment_df['questions'].apply(lambda x: [x] if type(x) != list else x)
endowment_df['options'] = endowment_df['options'].apply(lambda x: x[0])
endowment_df['type'] = endowment_df['options'].apply(lambda x: '')
endowment_df['difficulty_level'] = endowment_df['difficulty'].apply(lambda x: 4)
endowment_df['description'] = endowment_df.apply(lambda row: ["The question needs to test the endowment effect which is a behavioral bias where people are more likely to keep an object they have than sell it or trade for an object of higher value.", f"There should be {len(row['questions'])} questions.", "If there are two questions, each question should mirror the other in terms of the object being endowed.", f"The object should be {row['domain'].split(';')[1]}."], axis=1)
endowment_df
# Out:
#                                             questions  \
# 0   [During your lunch break, you buy a rare comic...
# 1   [You are a coffee enthusiast and bought a spec...
# 2   [You just got a limited edition book costing {...
# 3   [You've just purchased a new notebook that cos...
# 4   [You recently bought a new coffee mug for {} d...
# 5   [Imagine you've purchased a limited edition bo...
# 6   [After a hunt for a reliable coffee maker, you...
# 7   [You've been in search of a quality ergonomic ...
# 8   [You've bought a limited-edition notebook that...
# 9   [You acquire a coffee maker for your office fo...
# 10  [Heeding a good deal at a bookstore, you buy a...
# 11  [You purchase an ergonomic office chair for {}...
# 12  [For the family White Elephant gift exchange, ...
# 13  [You are at a family picnic where they are giv...
# 14  [You are at a cousin's birthday party where ev...
# 15  [On a father's day reef fishing trip, you land...
# ...

# %%
endowment_df.to_pickle('validate/endowment.pkl')
