# %%
import pandas as pd

# %% [markdown]
# # DataFrame of All Tasks

# %%
df = pd.DataFrame([
    {'Category': 'Arithmetic', "Task Name": "Can Add and Subtract",  "Tasks": ["Can Add and Subtract Integers", "Can Add and Subtract with Fractions", "Can Add and Subtract Large Numbers", ], "Difficulties": [0, 1, 2], },
    {'Category': 'Arithmetic', "Task Name": "Can Multiply and Divide", "Tasks": ["Can Multiply and Divide Integers", "Can Multiply and Divide with Fractions", "Can Multiply and Divide Large Numbers"], "Difficulties": [1, 2, 3], },
    {'Category': 'Probability', "Task Name": "Correctly Assigns Probabilities to Outcomes", "Tasks": ["Correctly Assigns Probabilities to a Single Outcome", "Correctly Assigns Probabilities to Few Outcomes", "Correctly Assigns Probabilities to Many Outcomes"], "Difficulties": [1, 2, 3], },
    {'Category': 'Probability', "Task Name": "Respects Complement Rule", "Tasks": ["Respects Complement Rule with Two Outcomes", "Respects Complement Rule with Three Outcomes", "Respects Complement Rule with Many Outcomes"], "Difficulties": [1, 2, 3], },
    {'Category': 'Probability', "Task Name": "Can Compute Joint Probabilities", "Tasks": ["Can Compute Joint Probabilities", "Can Compute Joint Probabilities Harder", "Can Compute Joint Probabilities Hardest"], "Difficulties": [3, 4, 5], },
    {'Category': 'Probability', "Task Name": "Can Compute Marginal Probabilities", "Tasks": ["Can Compute Marginal Probabilities", "Can Compute Marginal Probabilities Harder", "Can Compute Marginal Probabilities Hardest"], "Difficulties": [3, 4, 5], },
    {'Category': 'Probability', "Task Name": "Can Correctly Use Bayes Rule", "Tasks": ["Can Correctly Use Bayes Rule in Multiple Choice", "Can Correctly Use Bayes Rule in Open-Ended"], "Difficulties": [5, 6], },
    {'Category': 'Optimization', "Task Name": "Can Pick Biggest Number", "Tasks": ["Can Pick Biggest Integer", "Can Pick Biggest Fraction"], "Difficulties": [0, 1], },
    {'Category': 'Optimization', "Task Name": "Can Compute Unconstrained Optimization", "Tasks": ["Can Compute Simple Unconstrained Optimization", "Can Compute Harder Unconstrained Optimization"], "Difficulties": [2, 3], },
    {'Category': 'Optimization', "Task Name": "Can Compute Constrained Optimization", "Tasks": ["Can Compute Simple Constrained Optimization", "Can Compute Harder Constrained Optimization"], "Difficulties": [3, 4], },
    {'Category': 'Logic', "Task Name": "Can Identify Logically Equivalent Statements", "Tasks": ["Can Identify Simple Logically Equivalent Statements", "Can Identify Intermediate Logically Equivalent Statements", "Can Identify Hard Logically Equivalent Statements"], "Difficulties": [2, 3, 4], },
    {'Category': 'Theory of Mind', "Task Name": "Task",  "Tasks": ["Task Easy", "Task Hard"], "Difficulties": [3, 4], },
    {'Category': 'Utility Theory', "Task Name": "Respects Transitivity", "Tasks": ["Respects Transitivity Across Three Options", "Respects Transitivity Across Four Options", "Respects Transitivity Across Many Options"], "Difficulties": [2, 3, 4], },
    {'Category': 'Utility Theory', "Task Name": "Ignores Irrelevant Alternatives", "Tasks": ["Ignores a Single Irrelevant Alternative", "Ignores Two Irrelevant Alternatives", "Ignores Many Irrelevant Alternatives"], "Difficulties": [4, 5, 6], },
    # {'Category': 'Reference Independent Decision-Making', "Tasks": ["Unaffected by Peer Pressure"], "Difficulties": [7], },
    {'Category': 'Reference Independent Decision-Making', "Task Name": "Ignores Sunk Costs", "Tasks": ["Ignores Sunk Costs in One Option", "Ignores Sunk Costs Across Many Options"], "Difficulties": [7, 8], },
    # {'Category': 'Reference Independent Decision-Making', "Tasks": ["Unaffected by Status Quo"], "Difficulties": [7], },
    {'Category': 'Reference Independent Decision-Making', "Task Name": "Ignores Endowments", "Tasks": ["Unaffected by Being Endowed with One Item", "Unaffected by Being Endowed with Many Items"], "Difficulties": [6, 7], },
    {'Category': 'Reference Independent Decision-Making', "Task Name": "Consistent Discounting", "Tasks": ["Discounts Consistently Across a Few Time Steps", "Discounts Consistently Across Many Time Steps"], "Difficulties": [4, 5], },
    {'Category': 'Reference Independent Decision-Making', "Task Name": "Recalls Objects Agnostic to Ordering", "Tasks": ["Can Recall a Few Objects Agnostic to Ordering", "Can Recall Many Objects Agnostic to Ordering"], "Difficulties": [5, 6], },
    {'Category': 'Expected Utility Theory', "Task Name": "Can Compute Expected Utility",  "Tasks": ["Can Compute Expected Utility of Two Outcomes", "Can Compute Expected Utility of Three Outcomes", "Can Compute Two Expected Utilities of Many Outcomes", "Can Compute Many Expected Utilities of Many Outcomes"], "Difficulties": [3, 4, 5, 6], },
    {'Category': 'Expected Utility Theory', "Task Name": "Can Maximize Expected Utility", "Tasks": ["Can Maximize Expected Utility Between Two Options", "Can Maximize Expected Utility Between Three Options", "Can Maximize Between Many Expected Utilities of Three Outcomes", "Can Maximize Between Many Expected Utilities of Many Outcomes"], "Difficulties": [4, 5, 6, 7], },
    {'Category': 'Expected Utility Theory', "Task Name": "Computes Expectations with Objective Probabilities",  "Tasks": ["Computes Expectations of Few Outcomes with Objective Probabilities", "Computes Expectations of Many Outcomes with Objective Probabilities", ], "Difficulties": [7, 8, 9], },
    {'Category': 'Risk Assessment', "Task Name": "Does Not Make Risk Averting Decisions", "Tasks": ["Does Not Make Risk Averting Decisions in High Risk", "Does Not Make Risk Averting Decisions in Low Risk"], "Difficulties": [6, 7], },
    {'Category': 'Risk Assessment', "Task Name": "Does Not Make Risk Seeking Decisions", "Tasks": ["Does Not Make Risk Seeking Decisions in High Risk", "Does Not Make Risk Seeking Decisions in Low Risk"], "Difficulties": [6, 7], },
    {'Category': 'Risk Assessment', "Task Name": "Does Not Make Loss Averting Decisions", "Tasks": ["Does Not Make Loss Averting Decisions in High Loss", "Does Not Make Loss Averting Decisions in Low Loss"], "Difficulties": [6, 7], },
    {'Category': 'Risk Assessment', "Task Name": "Not Averse to Ambiguity in Choices", "Tasks": ["Not Averse to Ambiguity in Choices"], "Difficulties": [7], },
    # {'Category': 'Judgements Under Limited Data', "Task Name": "Can Make Accurate Judgements on Everyday Events", "Tasks": ["Can Make Accurate Judgements on Everyday Events", "Can Make Accurate Judgements on Everyday Events Harder"], "Difficulties": [6, 7], },
    {'Category': 'Single-Round Game Theory', "Task Name": "Can Interpret Games in Normal Form", "Tasks": ["Can Interpret 2x2 Normal Form", "Can Interpret 3x3 Normal Form", "Can Interpret XxX Normal Form"], "Difficulties": [2, 3, 4], },
    {'Category': 'Single-Round Game Theory', "Task Name": "Does not Play Dominated Strategies", "Tasks": ["Does Not Play Dominated Strategies in 2x2 Games", "Does Not Play Dominated Strategies in 3x3 Games", "Does Not Play Dominated Strategies in XxX Games"], "Difficulties": [3, 4, 5], },
    {'Category': 'Single-Round Game Theory',"Task Name":  "Can Best Respond", "Tasks": ["Can Best Respond in 2x2 Games", "Can Best Respond in 3x3 Games", "Can Best Respond in XxX Games"], "Difficulties": [5, 6, 7], },
    {'Category': 'Single-Round Game Theory', "Task Name":  "Can Find Pure Nash", "Tasks": ["Can Find Pure Nash in 2x2 Games","Can Find Pure Nash in 3x3 Games","Can Find Pure Nash in XxX Games"], "Difficulties": [9, 10, 11], },
    {'Category': 'Multi-Round Game Theory',"Task Name":  "Dynamically Responds to Actions", "Tasks": ["Dynamically Responds in 2x2 Games", "Dynamically Responds in 3x3 Games", "Dynamically Responds in XxX Games"], "Difficulties": [5, 6, 7], },
    {'Category': 'Multi-Round Game Theory', "Task Name":  "Can Find Subgame Perfect Nash", "Tasks": ["Can Find Subgame Perfect Nash in 3 Round Games","Can Find Subgame Perfect Nash in 4 Round Games","Can Find Subgame Perfect Nash in X Round Games"], "Difficulties": [9, 10, 11], },
]   
)

# %%
df.index = df.index.set_names(['task_id'])
df.reset_index().rename(columns={df.index.name:'task_id'})
# Out:
#     task_id                               Category  \
# 0         0                             Arithmetic
# 1         1                             Arithmetic
# 2         2                            Probability
# 3         3                            Probability
# 4         4                            Probability
# 5         5                            Probability
# 6         6                            Probability
# 7         7                           Optimization
# 8         8                           Optimization
# 9         9                           Optimization
# 10       10                                  Logic
# 11       11                         Theory of Mind
# 12       12                         Utility Theory
# 13       13                         Utility Theory
# 14       14  Reference Independent Decision-Making
# 15       15  Reference Independent Decision-Making
# 16       16  Reference Independent Decision-Making
# ...

# %%
# bayes rule may need to have something for it like "has a prior" or something
df['Dependencies'] = [(None), (0,), (0, 1), (0,), (0, 1, 2), (0, 1, 2), (0, 1, 2), (None), (0, 1), (0, 1), None, None, None, None, (0, 1), (0, 1), (0, 1, 7, 12), (None), (0, 1, 2, 3, 12, 13), (0, 1, 2, 3, 7, 12, 13), (0, 1, 2, 3, 7, 12, 13), (0, 1, 2, 3, 7, 12, 13), (0, 1, 2, 3, 7, 12, 13), (0, 1, 2, 3, 7, 12, 13),  (0, 1, 2, 3, 7, 12, 13), (0, 1, 2, 3, 6), (None), (7, 26), (7, 11, 26), (7, 11, 26)]

# %%
df
# Out:
#                                       Category  \
# task_id
# 0                                   Arithmetic
# 1                                   Arithmetic
# 2                                  Probability
# 3                                  Probability
# 4                                  Probability
# 5                                  Probability
# 6                                  Probability
# 7                                 Optimization
# 8                                 Optimization
# 9                                 Optimization
# 10                                       Logic
# 11                              Theory of Mind
# 12                              Utility Theory
# 13                              Utility Theory
# 14       Reference Independent Decision-Making
# 15       Reference Independent Decision-Making
# 16       Reference Independent Decision-Making
# 17       Reference Independent Decision-Making
# 18                     Expected Utility Theory
# ...

# %%
df.to_pickle('all_tasks.pkl')

# %%
pd.read_pickle('all_tasks.pkl')
# Out:
#                                       Category  \
# task_id
# 0                                   Arithmetic
# 1                                   Arithmetic
# 2                                  Probability
# 3                                  Probability
# 4                                  Probability
# 5                                  Probability
# 6                                  Probability
# 7                                 Optimization
# 8                                 Optimization
# 9                                 Optimization
# 10                                       Logic
# 11                              Theory of Mind
# 12                              Utility Theory
# 13                              Utility Theory
# 14       Reference Independent Decision-Making
# 15       Reference Independent Decision-Making
# 16       Reference Independent Decision-Making
# 17       Reference Independent Decision-Making
# 18                     Expected Utility Theory
# ...

# %%
for i, row in df.iterrows():
    print(row['Task Name'])
# Out:
# Can Add and Subtract
# Can Multiply and Divide
# Correctly Assigns Probabilities to Outcomes
# Respects Complement Rule
# Can Compute Joint Probabilities
# Can Compute Marginal Probabilities
# Can Correctly Use Bayes Rule
# Can Pick Biggest Number
# Can Compute Unconstrained Optimization
# Can Compute Constrained Optimization
# Can Correctly Identify Logically Equivalent Statements
# Task
# Respects Transitivity
# Ignores Irrelevant Alternatives
# Ignores Sunk Costs
# Ignores Endowments
# Consistent Discounting
# Recalls Objects Agnostic to Ordering
# Can Compute Expected Utility
# Can Maximize Expected Utility
# Does Not Make Risk Averting Decisions
# Does Not Make Risk Seeking Decisions
# Does Not Make Loss Averting Decisions
# Computes Expectations with Objective Probabilities
# Not Averse to Ambiguity in Choices
# Can Make Accurate Judgements on Everyday Events
# Can Interpret Games in Normal Form
# Does not Play Dominated Strategies
# Can Best Respond
# Can Find Pure Nash

# %% [markdown]
# # Convert to Validation DataFrame

# %%
import numpy as np
sunkcost_df = pd.read_pickle('../../rationality_benchmark/data_generation/preferences_gen/sunk_cost_total.pkl')
sunkcost_df = sunkcost_df[sunkcost_df.is_example == False]
sunkcost_df['validated'] = sunkcost_df.apply(lambda row: np.nan, axis=1)
type2desc = {'signal': 'The question should include text that signals this is about sunk cost fallacy, (i.e., you incur some sunk costs, you absorb the sunk costs, etc.)', 'other': 'The question should be from the perspective of some individual and not include words like you.', 'self': "The question should be from the perspective of the LLM and have pronouns like 'You do this'..."}
sunkcost_df['description'] = sunkcost_df.apply(lambda row: [f"This question is about {row['domain_description']}", "Sunk cost fallacy is when you make decisions that depend on costs that have already been incurred, rather than only on future costs.", f"The [BLANK] should be well-formed and correspond to numbers that make sense for sunk costs in the domain (both in options and questions).", f"{type2desc[row['type']]}"], axis=1)
sunkcost_df
# Out:
#                  domain                                 domain_description  \
# 17        medical;money  a dilemma between spending more money on the s...
# 18        medical;money  a dilemma between spending more money on the s...
# 19        medical;money  a dilemma between spending more money on the s...
# 20        medical;money  a dilemma between spending more money on the s...
# 21        medical;money  a dilemma between spending more money on the s...
# ...                 ...                                                ...
# 8377  responsible;money  a dilemma between spending more money on the s...
# 8378  responsible;money  a dilemma between spending more money on the s...
# 8379  responsible;money  a dilemma between spending more money on the s...
# 8380  responsible;money  a dilemma between spending more money on the s...
# 8381  responsible;money  a dilemma between spending more money on the s...
#
#       difficulty_level    type  \
# 17                   3  signal
# ...

# %%
sunkcost_df.to_pickle('sunk_cost.pkl')

# %%
ambiguity_df = pd.read_pickle('validate/ambiguity.pkl')
ambiguity_df['difficulty_level'] = ambiguity_df['difficulty'].apply(lambda x: 6)
ambiguity_df['type'] = ambiguity_df.apply(lambda row: '', axis = 1)
ambiguity_df['description'] = ambiguity_df['description'].apply(lambda x: ["The question should be testing for ambiguity aversion which is a behavioral bias in which given a gamble people prefer the known probability."]+x+["The first question should be a gamble only between an object with known probability and an object with unknown probability", "The second question should be a gamble between an object with known and unknown probability and a gamble with known probability."])
ambiguity_df.to_pickle('validate/ambiguity.pkl')

# %%
endowment_df = pd.read_pickle('validate/endowment.pkl')
endowment_df['questions'] = endowment_df['questions'].apply(lambda x: [x] if type(x) != list else x)
endowment_df['options'] = endowment_df['options'].apply(lambda x: x[0])
endowment_df['type'] = endowment_df['options'].apply(lambda x: '')
endowment_df['difficulty_level'] = endowment_df['difficulty'].apply(lambda x: 4)
endowment_df['description'] = endowment_df.apply(lambda row: ["The question needs to test the endowment effect which is a behavioral bias where people are more likely to keep an object they have than sell it or trade for an object of higher value.", f"There should be {len(row['questions'])} questions.", "If there are two questions, each question should mirror the other in terms of the object being endowed.", f"The object should be {row['domain'].split(';')[1]}."], axis=1)
endowment_df
# Out:
#                                             questions  \
# 0   [During your lunch break, you buy a rare comic...
# 1   [You are a coffee enthusiast and bought a spec...
# 2   [You just got a limited edition book costing {...
# 3   [You've just purchased a new notebook that cos...
# 4   [You recently bought a new coffee mug for {} d...
# 5   [Imagine you've purchased a limited edition bo...
# 6   [After a hunt for a reliable coffee maker, you...
# 7   [You've been in search of a quality ergonomic ...
# 8   [You've bought a limited-edition notebook that...
# 9   [You acquire a coffee maker for your office fo...
# 10  [Heeding a good deal at a bookstore, you buy a...
# 11  [You purchase an ergonomic office chair for {}...
# 12  [For the family White Elephant gift exchange, ...
# 13  [You are at a family picnic where they are giv...
# 14  [You are at a cousin's birthday party where ev...
# 15  [On a father's day reef fishing trip, you land...
# ...

# %%
endowment_df.to_pickle('validate/endowment.pkl')
